# %% [markdown]
# # The Capacitor
#
# With regard to the two sheets of opposite charge that concluded our previous notebook we suppose that each sheet has area $A$ and are separated by a distance $d$.
#
# The top (red) sheet has positive charge, $Q=\sigma A$, where $\sigma>0$, and so the field lines point away, while the bottom (blue) sheet has negative charge, $-Q = -\sigma A$, and so the field lines point in.
#
# Between the sheets, the field lines point in the same direction and so the resulting field is doubled, while above the red and below the blue to the field lines point in opposite directions and so cancel one another. Hence
#
# $$
#   \boxed{\vec E_{cap}(z) = \cases{(0,0,-4\pi k_e\sigma) &if 0<z<d \\ (0,0,0) & otherwise}}
# $$
#
# where cap is short for capacitor, the name of this object.
#
# In general, the **vector** Electric Field, $E$, is the gradient of a **scalar** Voltage, $V$. That is
#
# $$
#   \vec E(x,y,z) = -\left(\frac{\partial V(x,y,z)}{\partial x}, \frac{\partial V(x,y,z)}{\partial y}, \frac{\partial V(x,y,z)}{\partial z}\right)
# $$
#
# that is, **the $x$-component of the Electric field is the negative of the change in voltage with respect to $x$, and similarly for $y$ and $z$.**
#
# From this relationship we learn that dimension of Voltage is $N\, m/C$. As you recall, a Newton meter is a Joule, and so a **Volt is a Joule per Coulomb**.
#
# With respect to our capacitor we find the voltage (between the sheets) to be
#
# $$
#   V_{cap}(z) = 4\pi k_e\sigma z, \hskip 0.25in Volts
# $$
#
# This is $0$ on the bottom sheet and $4\pi k_e\sigma d$ on the top sheet. We find
#
# $$
#   V_{cap}(d) - V_{cap}(0) = 4\pi k_e\sigma d = 4\pi k_e Q d/A
# $$
#
# is typically rearranged in the form of the **Static Capacitor Law**
#
# $$
#   \boxed{C\Delta V = Q, \hskip 0.25in  C \equiv \frac{A}{4\pi k_e d}}
# $$
#
# where **C is the capacitance** and $\Delta V$ is the **voltage drop**. We see that capacitance is measured in units of charge per volt, i.e., charge squared per Joule, or, in honor of Michael Faraday, a **Farad**, or F for short.
#
# The Static Capacitor Law becomes Dynamic (and way more useful) when we allow the charge $Q$ to change with time. For **current** is precisely the change in charge with respect to time:
#
# $$
#   I = \frac{\Delta Q}{\Delta t} = Q'(t)
# $$
#
# which brings up the new unit **Ampere = Coulomb per Second** or **A=C/s** for short. Taking the time derivative of our static law now yields the **Dynamic Capacitor Law**
#
# $$
#   \boxed{C(\Delta V)'(t) = I(t)}
# $$
#
# In words, **the capacitance times the time rate of change of the voltage drop across the capacitor, equals the current.**

# %% [markdown]
# # Circuit Simulation
#
# In order to test these ideas, please
#
#     - sign up and sign in at tinkercad.com
#     - click on Circuits
#     - click on create new circuit
#     - build the circuit below using a 100 nF capacitor

# %%
# used https://www.base64-image.de/ to code my image
# copied code into data slot below, removing leading ..._data = "..."
display.Image(b64decode(base64_data))

# %% [markdown]
# You have now connected a capacitor to a 3 Volt battery through a switch and can monitor the voltage drop across the capacitor with a multimeter. On pressing the "Start Simulation" button the meter reads 3 Volts and this in effect charges the capacitor. If you now flip the switch the capacitor will discharge through the multimeter and you will see the voltage slowly decay to 0.
#
# Use the "Simulator time" just above the circuit to estimate the number of seconds, after flipping the switch, for the voltage to drop from 3 to 2 volts.
#
# **Exercise 1.** Do this for at least four capacitance levels, 100 nF, 200 nF, 300 nF and 400 nF and graph your findings in python - as in the cell below.

# %%
import matplotlib.pyplot as plt

Cap = [100, 200]   # you must add to these two lists
Dtime = [4, 8]

plt.plot(Cap, Dtime,'ko-')
plt.xlabel('Capacitance, nF')
plt.ylabel('Time to lose 1 volt, s')
plt.grid('on')

# %% [markdown]
# We will see in the next lesson that the rate at which the voltage drop decreases depends on the internal resistance of the multimeter.
#
# Before that let us explore how capacitors behave in series and **parallel**. The circuit below place two 100 nF capacitors in parallel (each leg touches a corresponding leg of the other capacitor). Measure the 1-volt decay time for this lay out as well as for 3 and 4 such capacitors in parallel.

# %%
from IPython import display 
from base64 import b64decode

base64_data = "..."
display.Image(b64decode(base64_data))

# %% [markdown]
# **Exercise 2:** Graph your findings in python - as in the cell below.

# %%
NCap = [1, 2]
DtimeP = [4, 8]

plt.plot(NCap, DtimeP,'ko-')
plt.title('Capacitors in Parallel')
plt.xlabel('Number of 100 nF Capacitors')
plt.ylabel('Time to lose 1 volt, s')
plt.grid('on')

# %% [markdown]
# The circuit below place two 400 nF capacitors in **series** (ONLY one leg touches a corresponding leg of the other capacitor). Measure the 1-volt decay time for this lay out as well as for 3 and 4 such capacitors in series. We have started with a larger value because series connections decrease capacitance.

# %%
from IPython import display 
from base64 import b64decode

base64_data = "..."
display.Image(b64decode(base64_data))

# %% [markdown]
# **Exercise 3:** Graph your findings in python - as in the cell below.

# %%
NCap = [1, 2]
DtimeS = [16, 8]

plt.plot(NCap, DtimeS,'ko-')
plt.title('Capacitors in Series')
plt.xlabel('Number of 400 nF Capacitors')
plt.ylabel('Time to lose 1 volt, s')
plt.grid('on')

# %%
**Homework 3.** Submit a jupyter notebook that demonstrates your solutions to Exercises 1-3.
